# %%
import numpy as np
import matplotlib.pyplot as plt
import math	
import sympy as sp
from matplotlib import cm
from sympy.abc import x,y,z,alpha,beta,pi,n
from matplotlib import style

# %%
style.use('ggplot')
y1 = (2*x-1)/(x-1)
sp.plot((y1,(x,-1,0.9)),(y1,(x,1.1,3)))
y2 = (2*x-1)/sp.Abs(x-1)
sp.plot((y2,(x,-1,0.9)),(y2,(x,1.1,3)))

# %% [markdown]
# 2.

# %%
style.use('ggplot')
y21 = (1+x)**(1/x)
sp.plot((y21,(x,0,1000)))
y22 = (sp.sin(x**2/sp.sqrt(1-x**3))/(x*sp.ln(1-x**3)))
sp.plot((y22,(x,0,0.001)))
# Out:
# <string>:1: RuntimeWarning: divide by zero encountered in cdouble_scalars
# <string>:1: RuntimeWarning: invalid value encountered in cdouble_scalars
# C:\Programs\Anaconda3\lib\site-packages\sympy\plotting\plot.py:1613: RuntimeWarning: invalid value encountered in subtract
#   vector_a = (x - y).astype(np.float64)
# C:\Programs\Anaconda3\lib\site-packages\sympy\plotting\plot.py:1614: RuntimeWarning: invalid value encountered in subtract
#   vector_b = (z - y).astype(np.float64)
# C:\Programs\Anaconda3\lib\site-packages\sympy\plotting\plot.py:1618: RuntimeWarning: invalid value encountered in double_scalars
#   cos_theta = dot_product / (vector_a_norm * vector_b_norm)

# %% [markdown]
# 3.

# %%
print(sp.limit(((1+x)**(1/x)),x,sp.oo))
print(sp.limit((sp.sin(x**2/sp.sqrt(1-x**3))/(x*sp.ln(1-x**3))),x,0))
# Out:
# 1
# -oo

# %% [markdown]
# C1

# %%
style.use('ggplot')
y3 = sp.Abs((2*x-1)/(x-1))
sp.plot((y3,(x,-1,0.9)),(y1,(x,1.1,3)))
y4 = sp.Abs(3*x-6)/(x-2)
sp.plot((y4,(x,-1,2)),(y4,(x,2,3)))

# %% [markdown]
# C2

# %%
style.use('ggplot')
yc21 = sp.ln(x)*sp.sin(x)
sp.plot((yc21,(x,0.1,100)))
yc22 = (2**x)/(sp.factorial(x))
sp.plot((yc22,(x,0,10)))

# %% [markdown]
# C3

# %%
print(sp.limit((sp.ln(x)*sp.sin(x)),x,sp.oo))
print(sp.limit(((2**x)/(sp.factorial(x))),x,sp.oo))
# Out:
# AccumBounds(-oo, oo)
# 0
